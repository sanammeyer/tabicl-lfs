# %%
import pandas as pd

data = pd.read_csv('cc18_tabicl_step-1000_pdl_posterior_avg.csv')

# %%
data
# Out:
#      task_id  dataset_id dataset_name  fold task_type  n_rows  n_features  \
# 0          3           3     kr-vs-kp   0.0    Binary    3196          36
# 1          3           3     kr-vs-kp   1.0    Binary    3196          36
# 2          3           3     kr-vs-kp   2.0    Binary    3196          36
# 3          3           3     kr-vs-kp   3.0    Binary    3196          36
# 4          3           3     kr-vs-kp   4.0    Binary    3196          36
# ..       ...         ...          ...   ...       ...     ...         ...
# 589   167141       40701        churn   5.0    Binary    5000          20
# 590   167141       40701        churn   6.0    Binary    5000          20
# 591   167141       40701        churn   7.0    Binary    5000          20
# 592   167141       40701        churn   8.0    Binary    5000          20
# 593   167141       40701        churn   9.0    Binary    5000          20
#
#      n_classes  imbalance_ratio  accuracy  ...  recall_macro   roc_auc  \
# ...

# %%
valid_datasets = data[data['n_valid_folds'] == 10]

# %%
num_datasets = valid_datasets['dataset_id'].nunique()
num_datasets
# Out:
# 58
